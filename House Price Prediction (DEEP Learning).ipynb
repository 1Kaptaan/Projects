# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['price'])

# %%
sns.boxplot(df['price'])

# %%
#we can ignore the outliers as there are not that many houses that are this expensive

# %%
sns.countplot(df['bedrooms'])

# %%
df[df['bedrooms']>7]
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 1658   9126101740   12/4/2014   490000.0         8       5.00         2800
# 4031    685000115   10/7/2014  2150000.0         8       6.00         4340
# 4063   7226500100   2/19/2015   373000.0         8       3.00         2850
# 4092   1997200215    5/7/2014   599999.0         9       4.50         3830
# 4231   2902200015    1/6/2015   700000.0         9       3.00         3680
# 6073   9822700190    8/8/2014  1280000.0         9       4.50         3650
# 6168   1873400020    7/3/2014   340000.0         8       2.75         2790
# 8537    424049043   8/11/2014   450000.0         9       7.50         4050
# 8748   1773100755   8/21/2014   520000.0        11       3.00         3000
# 9068   6746700615   3/18/2015   700000.0         8       2.50         2280
# 9443   2769600590  10/16/2014   900000.0         8       4.00         4020
# ...

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
#always explore highly correlated features

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='bathrooms',y='price',data=df)

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %%
df.sort_values(by='price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)
# Out:
# 21597

# %%
non_top_1_perc = df.sort_values(by='price',ascending=False).iloc[216:]

# %%
non_top_1_perc.max()['price']
# Out:
# 1970000.0

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,hue='price')

# %%
df.max()['price']
# Out:
# 7700000.0

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id',axis =1)

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date:date.month)

# %%
df['month'] = df['date'].apply(lambda date : date.month)

# %%
df=df.drop('year',axis = 1)

# %%
df['year'] = df['date'].apply(lambda date:date.year)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='price',y='month',data = df)

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='price',y='year',data = df)

# %%
df.groupby(by='month').mean()['price'].plot()

# %%
df = df.drop('date',axis = 1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# ...

# %%
df = df.drop('zipcode',axis = 1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df[df['yr_renovated']==0]['yr_renovated']
# Out:
# 0        0
# 2        0
# 3        0
# 4        0
# 5        0
#         ..
# 21592    0
# 21593    0
# 21594    0
# 21595    0
# 21596    0
# Name: yr_renovated, Length: 20683, dtype: int64

# %%
def renovated(df):
    if df['yr_renovated']==0:
        return 0
    else:
        return 1

# %%
df['yr_renovated']=df.apply(renovated,axis=1)

# %%
df['yr_renovated']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 21592    0
# 21593    0
# 21594    0
# 21595    0
# 21596    0
# Name: yr_renovated, Length: 21597, dtype: int64

# %%
df['yr_renovated'].value_counts()
# Out:
# 0    20683
# 1      914
# Name: yr_renovated, dtype: int64

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
X = df.drop('price',axis =1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
#from sklearn.linear_model import LogisticRegression

# %%
#lr = LogisticRegression(max_iter=2000)
#tried doing this it takes hell lot of a time

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
#WE make are nuerons as the size of our feature data
model = Sequential()

model.add(Dense(19,activation = 'relu'))
model.add(Dense(19,activation = 'relu'))
model.add(Dense(19,activation = 'relu'))
model.add(Dense(19,activation = 'relu'))

model.add(Dense(1))
#this is the final layer and has one nueron as we are only getting output here

model.compile(optimizer='adam',loss='mse')

# %%
#validation data will make the model check every time a cycle is complete
#batch sixe is to pass small batches and not the complete data through the model
#epoch is basically the number of times data will be passed
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,
          epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 2ms/step - loss: 430241251328.0000 - val_loss: 418925314048.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 1ms/step - loss: 429334757376.0000 - val_loss: 415682658304.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 1ms/step - loss: 415610961920.0000 - val_loss: 383716229120.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 1ms/step - loss: 345280413696.0000 - val_loss: 268054347776.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 197128044544.0000 - val_loss: 122191511552.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 106440998912.0000 - val_loss: 95492743168.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 1ms/step - loss: 97850097664.0000 - val_loss: 93822812160.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
#This shows that there is no issue
#both loss and validation loss are going same
#If the orange line goes up then we have overfitting and the model is not godd enough

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_log_error,explained_variance_score,mean_squared_error

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([[398330.8 ],
#        [585636.4 ],
#        [586539.2 ],
#        ...,
#        [395295.44],
#        [554495.7 ],
#        [673132.4 ]], dtype=float32)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 26889553329.488834

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 100817.15876494984

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7972513027401685

# %%
plt.figure(figsize=(12,5))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')
#the red line is the best possible 
#so we can retrain to get a better prediction

# %%
#TO predict on a brand new house

# %%
single_house = df.iloc[0].drop('price')

# %%
single_house.values.reshape(-1,19)
#negative one is to keep all the old Dimensions along the axis
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  1.00000e+01,  2.01400e+03]])

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
house_price = model.predict(single_house)

# %%
house_price
# Out:
# array([[285013.84]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# month                10.0000
# year               2014.0000
# Name: 0, dtype: float64
